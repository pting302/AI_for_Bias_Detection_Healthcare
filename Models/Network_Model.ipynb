# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_test = pd.read_csv(r"C:\Users\tingp\AI_for_Bias_Detection_Healthcare\Data\Test_Data.csv")
df_train = pd.read_csv(r"C:\Users\tingp\AI_for_Bias_Detection_Healthcare\Data\Training Data.csv")

# %%
df_test.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0     252327498     35998668        Caucasian    Male   [60-70)      ?
# 1     252329064     87987879        Caucasian  Female   [50-60)      ?
# 2     252331596     44574552        Caucasian    Male   [50-60)      ?
# 3     252353994     86337810  AfricanAmerican    Male  [90-100)      ?
# 4     252355998     47016477        Caucasian  Female   [50-60)      ?
# 5     252358164     90716346        Caucasian    Male   [40-50)      ?
# 6     252360360     84345759        Caucasian  Female   [80-90)      ?
# 7     252363006     27683469        Caucasian  Female   [70-80)      ?
# 8     252372264     87976440  AfricanAmerican  Female   [60-70)      ?
# 9     252381744     41624226        Caucasian    Male   [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  3                         1                    1
# ...

# %%
df_test.shape
# Out:
# (10177, 50)

# %%
# try implementing class based
